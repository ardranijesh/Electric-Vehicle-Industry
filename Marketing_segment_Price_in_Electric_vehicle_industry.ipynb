# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
warnings.filterwarnings('ignore')

# %%
price_change= pd.read_csv('Petrol Price change .csv')

# %%
price_change
# Out:
#     YEAR      MONTH       DATE  PETROL PRICE RS./LIT
# 0   2017        May  01-May-17                 68.09
# 1   2017        May  01-May-17                 68.09
# 2   2017       June  01-Jun-17                 66.91
# 3   2017       July  01-Jul-17                 63.09
# 4   2017     August  01-Aug-17                 65.40
# ..   ...        ...        ...                   ...
# 64  2022     August  01-Aug-22                 96.72
# 65  2022  September  01-Sep-22                 96.72
# 66  2022    October  01-Oct-22                 96.72
# 67  2022   November  01-Nov-22                 96.72
# 68  2023        May  01-May-23                 96.72
#
# [69 rows x 4 columns]

# %%
plt.figure(figsize=(20, 6))
sns.barplot('DATE', 'PETROL PRICE RS./LIT', data=price_change)
plt.title('Petrol Price change' , fontsize = 16)
plt.ylabel('Petrol Price change')
plt.xlabel('date')
plt.xticks(rotation=75)
plt.show()

# %%
plt.figure(figsize=(20, 6))
sns.barplot('YEAR', 'PETROL PRICE RS./LIT', data=price_change)
plt.title('Petrol Price change' , fontsize = 16)
plt.ylabel('Petrol Price change')
plt.xlabel('date')
plt.xticks(rotation=75)
plt.show()

# %%
data=pd.read_csv("states_data_car.csv")
data.head(20)
# Out:
#                 state             capital  subsidy  road tax  petrol  diesel
# 0      Andhra Pradesh           Amaravati      0.0      1.00  111.65   99.41
# 1   Arunachal Pradesh            Itanagar   5000.0      0.00   95.89   84.81
# 2               Assam              Dispur  10000.0      1.00   96.34   84.24
# 3               Bihar               Patna  10000.0      1.00  109.17   95.82
# 4        Chhattisgarh              Raipur   5000.0      0.00  102.98   95.96
# 5                 Goa              Panaji   8000.0      1.00   97.82   90.37
# 6             Gujarat         Gandhinagar  10000.0      0.50   96.49   92.23
# 7             Haryana          Chandigarh      0.0      0.00   97.24   90.08
# 8    Himachal Pradesh              Shimla   5000.0      0.00   95.74   81.99
# 9           Jharkhand              Ranchi   5000.0      0.00  100.09   94.88
# 10          Karnataka           Bengaluru      0.0      1.00  102.64   88.55
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   state     36 non-null     object
#  1   capital   36 non-null     object
#  2   subsidy   36 non-null     float64
#  3   road tax  36 non-null     float64
#  4   petrol    36 non-null     float64
#  5   diesel    36 non-null     float64
# dtypes: float64(4), object(2)
# memory usage: 1.8+ KB

# %%
data.isnull().sum()
# Out:
# state       0
# capital     0
# subsidy     0
# road tax    0
# petrol      0
# diesel      0
# dtype: int64

# %%
sns.countplot(x=data["road tax"])
plt.title('Count plot of road tax')
plt.xlabel('road tax')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(20, 5))
sns.barplot('state', 'petrol', data=data)
plt.title('Petrol Price in Different States' , fontsize = 16)
plt.ylabel('Petrol Price')
plt.xlabel('State Name')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20, 6))
sns.barplot('state', 'diesel', data=data)
plt.title('Diesel Price at different states' , fontsize = 16)
plt.ylabel('Diesel Price')
plt.xlabel('State Name')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Conclusion
#
# Electric vehicles (EVs) have emerged as a superior choice over traditional vehicles in the face of skyrocketing petrol prices. With the increasing cost of petrol, EVs offer substantial savings on fuel expenses due to their efficiency in utilizing electricity as a fuel source. Moreover, EV owners benefit from stable and predictable energy prices, as electricity costs tend to be less volatile compared to petrol. In addition to cost savings, EVs require lower maintenance and operating costs due to their simplified mechanics and regenerative braking systems. Governments worldwide are also incentivizing the adoption of EVs through subsidies and tax credits. Ultimately, choosing an electric vehicle not only provides financial advantages but also contributes to a cleaner and greener future.
